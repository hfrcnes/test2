# %% [markdown]
# # Search and massive download
# In this example, we will search for items using pygeodes, filter these items using geopandas dataframes and use a download queue to downloads these items and monitor the progress of the download.

# %% [markdown]
# ## Imports
# Let's start by importing geodes

# %%
from pygeodes import Geodes, Config

# %% [markdown]
# ## Configuration
# We configure using a config file located in our cwd

# %%
conf = Config.from_file("config.json")
geodes = Geodes(conf=conf)

# %% [markdown]
# ## Searching products
# We search for products in the *T31TCK* tile whose acquisition date is after *2023-01-01*

# %%
from pygeodes.utils.datetime_utils import complete_datetime_from_str

query = {
    "spaceborne:tile": {"eq": "T31TCK"},
    "temporal:endDate": {"gte": complete_datetime_from_str("2023-01-01")},
}
items, dataframe = geodes.search_items(query=query)
# Out:
# Found 230 items matching your query
# 230 item(s) found for query : {'spaceborne:tile': {'eq': 'T31TCK'}, 'temporal:endDate': {'gte': '2023-01-01T00:00:00.000000Z'}}

# %% [markdown]
# ### Exploring results
# We get a list ot items and a dataframe, we can work with the dataframe for instance :

# %%
dataframe
# Out:
#              temporal:endDate   collection spaceborne:tile  \
# 0    2024-03-08T10:57:59.024Z  PEPS_S2_L1C          T31TCK
# 1    2024-03-05T10:48:19.024Z  PEPS_S2_L1C          T31TCK
# 2    2024-03-03T10:59:41.024Z  PEPS_S2_L1C          T31TCK
# 3    2024-03-25T10:46:39.024Z  PEPS_S2_L1C          T31TCK
# 4    2024-03-20T10:47:41.024Z  PEPS_S2_L1C          T31TCK
# ..                        ...          ...             ...
# 225  2023-02-24T10:50:31.024Z  PEPS_S2_L1C          T31TCK
# 226  2023-03-21T10:46:49.025Z  PEPS_S2_L1C          T31TCK
# 227  2023-03-19T10:57:51.024Z  PEPS_S2_L1C          T31TCK
# 228  2023-02-22T10:59:49.025Z  PEPS_S2_L1C          T31TCK
# 229  2023-03-06T10:49:21.024Z  PEPS_S2_L1C          T31TCK
#
#                                                     id  \
# 0    URN:FEATURE:DATA:gdh:05a48805-adbc-3990-a096-f...
# 1    URN:FEATURE:DATA:gdh:243e16e2-ac59-3b62-adc5-8...
# 2    URN:FEATURE:DATA:gdh:e6658cda-5f8a-3d19-b9a3-c...
# 3    URN:FEATURE:DATA:gdh:7ad8089d-ac8d-33d9-b8c0-e...
# 4    URN:FEATURE:DATA:gdh:4ba686ff-6a4b-3e67-80b6-8...
# ..                                                 ...
# 225  URN:FEATURE:DATA:gdh:3993b481-0d71-3896-9235-3...
# 226  URN:FEATURE:DATA:gdh:8378ae65-ea65-331a-b414-c...
# 227  URN:FEATURE:DATA:gdh:1ac38aab-397a-3093-a9ad-b...
# 228  URN:FEATURE:DATA:gdh:339b2fdd-a973-3c34-9c6e-b...
# 229  URN:FEATURE:DATA:gdh:51042660-e4b6-39da-aec7-0...
#
#                                                   item  \
# 0    Item (URN:FEATURE:DATA:gdh:05a48805-adbc-3990-...
# 1    Item (URN:FEATURE:DATA:gdh:243e16e2-ac59-3b62-...
# 2    Item (URN:FEATURE:DATA:gdh:e6658cda-5f8a-3d19-...
# 3    Item (URN:FEATURE:DATA:gdh:7ad8089d-ac8d-33d9-...
# 4    Item (URN:FEATURE:DATA:gdh:4ba686ff-6a4b-3e67-...
# ..                                                 ...
# 225  Item (URN:FEATURE:DATA:gdh:3993b481-0d71-3896-...
# 226  Item (URN:FEATURE:DATA:gdh:8378ae65-ea65-331a-...
# 227  Item (URN:FEATURE:DATA:gdh:1ac38aab-397a-3093-...
# 228  Item (URN:FEATURE:DATA:gdh:339b2fdd-a973-3c34-...
# 229  Item (URN:FEATURE:DATA:gdh:51042660-e4b6-39da-...
#
#                                               geometry
# 0    POLYGON ((0.98016 45.13397, 0.45686 45.12551, ...
# 1    POLYGON ((0.45686 45.12551, 0.49965 44.13800, ...
# 2    POLYGON ((0.94824 45.13346, 0.45686 45.12551, ...
# 3    POLYGON ((0.45686 45.12551, 0.49965 44.13800, ...
# 4    POLYGON ((0.45686 45.12551, 0.49965 44.13800, ...
# ..                                                 ...
# 225  POLYGON ((0.49965 44.13800, 1.87192 44.15980, ...
# 226  POLYGON ((0.49965 44.13800, 1.87192 44.15980, ...
# 227  POLYGON ((0.49965 44.13800, 0.55302 44.13884, ...
# 228  POLYGON ((0.49965 44.13800, 0.55960 44.13895, ...
# 229  POLYGON ((0.49965 44.13800, 1.87192 44.15980, ...
#
# [230 rows x 6 columns]

# %% [markdown]
# ### Adding columns
# We want to filter on cloudcover, so we need to add the column to the dataframe.

# %%
items[0].list_available_keys()
# Out:
# {'accessService:endpointDescription',
#  'accessService:endpointURL',
#  'dataType',
#  'datetime',
#  'id',
#  'latest',
#  'spaceborne:absoluteOrbitID',
#  'spaceborne:cloudCover',
#  'spaceborne:continentsID',
#  'spaceborne:keywords',
#  'spaceborne:orbitDirection',
#  'spaceborne:orbitID',
#  'spaceborne:political.continents',
#  'spaceborne:productLevel',
#  'spaceborne:productTimeliness',
#  'spaceborne:productType',
#  'spaceborne:references',
#  'spaceborne:satellitePlatform',
#  'spaceborne:satelliteSensor',
#  'spaceborne:sensorMode',
#  'spaceborne:tile',
#  'spatial:bbox',
#  'temporal:endDate',
#  'temporal:startDate',
#  'versionInfo'}

# %% [markdown]
# We find we can use `spaceborne:cloudCover`, so we add it to the dataframe :

# %%
from pygeodes.utils.formatting import format_items

dataframe_new = format_items(dataframe, {"spaceborne:cloudCover"})

# %% [markdown]
# ### Filtering our results
# Now that the cloud cover is in our dataframe, we can filter on it.

# %%
dataframe_filtered = dataframe_new[dataframe_new["spaceborne:cloudCover"] < 30]

# %%
dataframe_filtered
# Out:
#              temporal:endDate   collection spaceborne:tile  \
# 6    2024-05-09T10:50:31.024Z  PEPS_S2_L1C          T31TCK
# 7    2024-02-17T11:00:19.024Z  PEPS_S2_L1C          T31TCK
# 8    2024-01-20T10:53:41.024Z  PEPS_S2_L1C          T31TCK
# 9    2024-04-12T10:56:21.024Z  PEPS_S2_L1C          T31TCK
# 14   2023-12-14T11:04:41.024Z  PEPS_S2_L1C          T31TCK
# ..                        ...          ...             ...
# 212  2023-05-18T10:56:21.024Z  PEPS_S2_L1C          T31TCK
# 216  2023-05-28T10:56:21.024Z  PEPS_S2_L1C          T31TCK
# 217  2023-05-30T10:46:29.024Z  PEPS_S2_L1C          T31TCK
# 219  2023-02-02T11:01:59.024Z  PEPS_S2_L1C          T31TCK
# 222  2023-02-04T10:52:41.024Z  PEPS_S2_L1C          T31TCK
#
#                                                     id  \
# 6    URN:FEATURE:DATA:gdh:bee1e3b7-84b7-332d-a06f-5...
# 7    URN:FEATURE:DATA:gdh:5c1379a6-702e-3f27-9cc0-2...
# 8    URN:FEATURE:DATA:gdh:084acd27-8d81-3dd1-adac-6...
# 9    URN:FEATURE:DATA:gdh:c3aa6a8a-c476-38d8-98a6-1...
# 14   URN:FEATURE:DATA:gdh:feabfb13-c300-3e2b-af2f-1...
# ..                                                 ...
# 212  URN:FEATURE:DATA:gdh:6145129d-6c0d-3281-8888-a...
# 216  URN:FEATURE:DATA:gdh:77280154-2e39-387c-998e-9...
# 217  URN:FEATURE:DATA:gdh:3aa7fac0-a6f1-3bb4-b4ec-a...
# 219  URN:FEATURE:DATA:gdh:a5133774-bbf3-33de-a735-2...
# 222  URN:FEATURE:DATA:gdh:bf33c962-58ea-3907-b3a8-1...
#
#                                                   item  \
# 6    Item (URN:FEATURE:DATA:gdh:bee1e3b7-84b7-332d-...
# 7    Item (URN:FEATURE:DATA:gdh:5c1379a6-702e-3f27-...
# 8    Item (URN:FEATURE:DATA:gdh:084acd27-8d81-3dd1-...
# 9    Item (URN:FEATURE:DATA:gdh:c3aa6a8a-c476-38d8-...
# 14   Item (URN:FEATURE:DATA:gdh:feabfb13-c300-3e2b-...
# ..                                                 ...
# 212  Item (URN:FEATURE:DATA:gdh:6145129d-6c0d-3281-...
# 216  Item (URN:FEATURE:DATA:gdh:77280154-2e39-387c-...
# 217  Item (URN:FEATURE:DATA:gdh:3aa7fac0-a6f1-3bb4-...
# 219  Item (URN:FEATURE:DATA:gdh:a5133774-bbf3-33de-...
# 222  Item (URN:FEATURE:DATA:gdh:bf33c962-58ea-3907-...
#
#                                               geometry  spaceborne:cloudCover
# 6    POLYGON ((0.45686 45.12551, 0.49965 44.13800, ...               0.000000
# 7    POLYGON ((0.94737 45.13344, 0.45686 45.12551, ...               3.435898
# 8    POLYGON ((0.45686 45.12551, 0.49965 44.13800, ...               0.553047
# 9    POLYGON ((0.95063 45.13349, 0.45686 45.12551, ...               9.792046
# 14   POLYGON ((0.96381 45.13371, 0.45686 45.12551, ...               0.000000
# ..                                                 ...                    ...
# 212  POLYGON ((0.49965 44.13800, 0.54921 44.13878, ...              25.458779
# 216  POLYGON ((0.49965 44.13800, 0.54324 44.13869, ...               0.000000
# 217  POLYGON ((0.49965 44.13800, 1.87192 44.15980, ...              29.690137
# 219  POLYGON ((0.49965 44.13800, 0.56934 44.13910, ...               0.445192
# 222  POLYGON ((0.49965 44.13800, 1.87192 44.15980, ...               0.292335
#
# [73 rows x 7 columns]

# %% [markdown]
# ## Plotting

# %% [markdown]
# We can plot our results on a map :

# %%
dataframe_filtered.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee14b2dca886f81cd7dce66fa85b33dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee14b2dca886f81cd7dce66fa85b33dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee14b2dca886f81cd7dce66fa85b33dd = L.map(
#                 &quot;map_ee14b2dca886f81cd7dce66fa85b33dd&quot;,
#                 {
#                     center: [44.643034965534, 1.164389610548435],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ee14b2dca886f81cd7dce66fa85b33dd);
#
#
#
#
#
#             var tile_layer_398856e1694f42aed2c2f8ce9cbae3bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_398856e1694f42aed2c2f8ce9cbae3bc.addTo(map_ee14b2dca886f81cd7dce66fa85b33dd);
#
#
#             map_ee14b2dca886f81cd7dce66fa85b33dd.fitBounds(
#                 [[44.137996748197, 0.45686051699677], [45.148073182871, 1.8719187041001]],
#                 {}
#             );
#
#
#         function geo_json_3c8ec6e80f52dd37719fde81f956e804_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3c8ec6e80f52dd37719fde81f956e804_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3c8ec6e80f52dd37719fde81f956e804_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3c8ec6e80f52dd37719fde81f956e804_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3c8ec6e80f52dd37719fde81f956e804_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3c8ec6e80f52dd37719fde81f956e804.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3c8ec6e80f52dd37719fde81f956e804_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3c8ec6e80f52dd37719fde81f956e804 = L.geoJson(null, {
#                 onEachFeature: geo_json_3c8ec6e80f52dd37719fde81f956e804_onEachFeature,
#
#                 style: geo_json_3c8ec6e80f52dd37719fde81f956e804_styler,
#                 pointToLayer: geo_json_3c8ec6e80f52dd37719fde81f956e804_pointToLayer,
#         });
#
#         function geo_json_3c8ec6e80f52dd37719fde81f956e804_add (data) {
#             geo_json_3c8ec6e80f52dd37719fde81f956e804
#                 .addData(data);
#         }
#             geo_json_3c8ec6e80f52dd37719fde81f956e804_add({&quot;bbox&quot;: [0.45686051699677, 44.137996748197, 1.8719187041001, 45.148073182871], &quot;features&quot;: [{&quot;bbox&quot;: [0.45686051699677, 44.137996748197, 1.8719187041001, 45.148073182871], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[0.45686051699677, 45.125513562024], [0.49965161310688, 44.137996748197], [1.8719187041001, 44.159796633711], [1.8525926183827, 45.148073182871], [0.45686051699677, 45.125513562024]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;collection&quot;: &quot;PEPS_S2_L1C&quot;, &quot;id&quot;: &quot;URN:FEATURE:DATA:gdh:bee1e3b7-84b7-332d-a06f-5c12e84d3582:V1&quot;, &quot;item&quot;: {&quot;assets&quot;: {&quot;2024/05/09/S2A/S2A_MSIL1C_20240509T105031_N0510_R0

# %% [markdown]
# ## Downloading our items

# %% [markdown]
# We can download our results using the Profile system

# %%
from pygeodes.utils.profile import DownloadQueue, Profile

# %% [markdown]
# We reset our Profile to be sure to track only the downloads from the queue

# %%
Profile.reset()
items = dataframe_filtered["item"].values
queue = DownloadQueue(items)

# %% [markdown]
# In a **separate cell**, we run our queue

# %%
queue.run()
